# %% [markdown]
# ## Review the execution environment

# %%
## development environment
# keras=2.2.4
# tensorflow=1.12.0
# dask=1.1.1
import keras
import tensorflow as tf
import dask

import warnings
warnings.filterwarnings('ignore')

print("keras={}".format(keras.__version__))
print("tensorflow={}".format(tf.__version__))
print("dask={}".format(dask.__version__))
# Out:
# /Users/jaejinan/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# keras=2.2.4
# tensorflow=1.12.0
# dask=1.1.1

# %% [markdown]
# ## Import module

# %%
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,Dense,Flatten,Dropout
from keras import backend as K
import numpy as np
import pandas as pd
import os
import cv2
from PIL import Image
import time

# %% [markdown]
# ## Import and save images

# %%
data=[]
labels=[]
Parasitized=os.listdir("./cell_images/Parasitized/")
for a in Parasitized:
    try:
        image=cv2.imread("./cell_images/Parasitized/"+a)
        image_from_array = Image.fromarray(image, 'RGB')
        size_image = image_from_array.resize((64, 64))
        data.append(np.array(size_image))
        labels.append(0)
    except AttributeError:
        print("")

Uninfected=os.listdir("./cell_images/Uninfected/")
for b in Uninfected:
    try:
        image=cv2.imread("./cell_images/Uninfected/"+b)
        image_from_array = Image.fromarray(image, 'RGB')
        size_image = image_from_array.resize((64, 64))
        data.append(np.array(size_image))
        labels.append(1)
    except AttributeError:
        print("")

# %%
Cells=np.array(data)
labels=np.array(labels)

# %%
np.save("Cells",Cells)
np.save("labels",labels)

# %% [markdown]
# ## Load Images

# %%
Cells=np.load("Cells.npy")
labels=np.load("labels.npy")

# %% [markdown]
# ## Data preprocessing

# %%
s=np.arange(Cells.shape[0])
np.random.shuffle(s)
Cells=Cells[s]
labels=labels[s]

# %%
num_classes=len(np.unique(labels))
len_data=len(Cells)

# %%
(x_train,x_test)=Cells[(int)(0.1*len_data):],Cells[:(int)(0.1*len_data)]
x_train = x_train.astype('float32')/255 # As we are working on image data we are normalizing data by divinding 255.
x_test = x_test.astype('float32')/255
train_len=len(x_train)
test_len=len(x_test)

# %%
(y_train,y_test)=labels[(int)(0.1*len_data):],labels[:(int)(0.1*len_data)]

# %%
y_train=keras.utils.to_categorical(y_train,num_classes)
y_test=keras.utils.to_categorical(y_test,num_classes)

# %%
img_rows, img_cols = 64,64
img_channels = 3

# %%
# Adjustment of input type of dimension number due to difference of backend

if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 3, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 3, img_rows, img_cols)
    input_shape = (3, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 3)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 3)
    input_shape = (img_rows, img_cols, 3)

# %% [markdown]
# ## Visualization of data

# %%
#read library for visualization
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
#preparing label name
labels = np.array([
    'Parasitized',
    'Uninfected'])

# %%
#Store 10 images for each label
img_list = []
for for_1 in range(len(labels)):
    choice_idx = np.random.choice(np.where(y_test == for_1)[0], 10)
    img_list.append(x_test[choice_idx])

# %%
# Visualization of data
for for_1 in range(len(labels)):
    fig, ax = plt.subplots(1, 10, figsize=(18, 8))
    for for_2 in range(10):
        ax[for_2].imshow(img_list[for_1][for_2].reshape(64, 64, 3)) #Outputs the nth and subsequent test data with the value of for_2 + n
        ax[for_2].set_title(labels[for_1])
        ax[for_2].axis('off')

# %% [markdown]
# ## Building a model

# %%
model=Sequential()
model.add(MaxPooling2D(pool_size=2, input_shape=(64,64,3)))
model.add(Conv2D(filters=10,kernel_size=4,padding="same",activation="relu"))
model.add(MaxPooling2D(pool_size=4))
model.add(Conv2D(filters=14,kernel_size=3,padding="same",activation="relu"))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(14,activation="relu"))
model.add(Dropout(0.2))
model.add(Dense(2,activation="softmax"))#2 represent output layer neurons 
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 64, 64, 8)         1544
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 8)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 16)        2064
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 16)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 32)          2080
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 32)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 32)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                32832
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 38,650
# Trainable params: 38,650
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Set model optimization function and error function

# %%
from keras.optimizers import Adam

model.compile(loss='categorical_crossentropy', 
              optimizer='adam', 
              metrics=['accuracy'])

# %% [markdown]
# ## Save model and parameters

# %%
#Save model in JSON format
json_string = model.to_json()
open('./cell_cnn.json', 'w').write(json_string)
# Out:
# 3795

# %%
#Save initial weight
model.save_weights('./cell_cnn_init_weight.hdf5', overwrite=True)

# %% [markdown]
# ## Reading models and calling parameters

# %%
# from keras.models import model_from_json, model_from_yaml
# Calling models saved in JSON format
# json_string = open('./cell_cnn.json', 'r').read()
# model = model_from_json(json_string)
# model.load_weights('./cell_cnn_init_weight.hdf5')

# %% [markdown]
# ## Learning

# %%
#See progress of learning at TensorBoard
tb_cb = keras.callbacks.TensorBoard(log_dir='/tmp/keras_cnn', histogram_freq=1)

# If the validation loss decreases, save the model for each epoch
cp_cb = keras.callbacks.ModelCheckpoint(filepath='./cell_cnn_best_weight1.hdf5', 
                                        monitor='val_loss', 
                                        verbose=1, 
                                        save_best_only=True, 
                                        mode='auto')

# If the validation loss rises for 5 epochs in a row, the run is aborted
es_cb = keras.callbacks.EarlyStopping(monitor='val_loss', 
                                      patience=5, 
                                      verbose=0, 
                                      mode='auto')

cbks = [tb_cb, cp_cb, es_cb]

# %%
#Perform learning
#The value of loss function in learning is stored in history.history
history = model.fit(x_train, y_train,
                    batch_size=128,  #128 datas are randomly obtained
                    nb_epoch=20, #Number of trials
                    verbose=1,
                    validation_data=(x_test, y_test),
                    callbacks=cbks)
# Out:
# Train on 24803 samples, validate on 2755 samples
# Epoch 1/20
# 24803/24803 [==============================] - 61s 2ms/step - loss: 0.5881 - acc: 0.6710 - val_loss: 0.4035 - val_acc: 0.8207
#
# Epoch 00001: val_loss improved from inf to 0.40352, saving model to ./cell_cnn_best_weight1.hdf5
# Epoch 2/20
# 24803/24803 [==============================] - 61s 2ms/step - loss: 0.2613 - acc: 0.8964 - val_loss: 0.1946 - val_acc: 0.9307
#
# Epoch 00002: val_loss improved from 0.40352 to 0.19456, saving model to ./cell_cnn_best_weight1.hdf5
# Epoch 3/20
# 24803/24803 [==============================] - 61s 2ms/step - loss: 0.1717 - acc: 0.9406 - val_loss: 0.1681 - val_acc: 0.9416
#
# Epoch 00003: val_loss improved from 0.19456 to 0.16814, saving model to ./cell_cnn_best_weight1.hdf5
# Epoch 4/20
# 24803/24803 [==============================] - 60s 2ms/step - loss: 0.1518 - acc: 0.9500 - val_loss: 0.1564 - val_acc: 0.9448
#
# Epoch 00004: val_loss improved from 0.16814 to 0.15644, saving model to ./cell_cnn_best_weight1.hdf5
# Epoch 5/20
# 24803/24803 [==============================] - 60s 2ms/step - loss: 0.1438 - acc: 0.9518 - val_loss: 0.1510 - val_acc: 0.9477
#
# Epoch 00005: val_loss improved from 0.15644 to 0.15104, saving model to ./cell_cnn_best_weight1.hdf5
# Epoch 6/20
# 24803/24803 [==============================] - 61s 2ms/step - loss: 0.1378 - acc: 0.9542 - val_loss: 0.1521 - val_acc: 0.9495
#
# Epoch 00006: val_loss did not improve from 0.15104
# Epoch 7/20
# 24803/24803 [==============================] - 60s 2ms/step - loss: 0.1324 - acc: 0.9566 - val_loss: 0.1503 - val_acc: 0.9510
#
# Epoch 00007: val_loss improved from 0.15104 to 0.15030, saving model to ./cell_cnn_best_weight1.hdf5
# Epoch 8/20
# 24803/24803 [==============================] - 61s 2ms/step - loss: 0.1288 - acc: 0.9566 - val_loss: 0.1531 - val_acc: 0.9488
#
# Epoch 00008: val_loss did not improve from 0.15030
# Epoch 9/20
# 24803/24803 [==============================] - 60s 2ms/step - loss: 0.1275 - acc: 0.9571 - val_loss: 0.1454 - val_acc: 0.9535
#
# Epoch 00009: val_loss improved from 0.15030 to 0.14539, saving model to ./cell_cnn_best_weight1.hdf5
# Epoch 10/20
# 24803/24803 [==============================] - 60s 2ms/step - loss: 0.1246 - acc: 0.9579 - val_loss: 0.1482 - val_acc: 0.9441
#
# Epoch 00010: val_loss did not improve from 0.14539
# Epoch 11/20
# 24803/24803 [==============================] - 60s 2ms/step - loss: 0.1221 - acc: 0.9598 - val_loss: 0.1406 - val_acc: 0.9525
#
# Epoch 00011: val_loss improved from 0.14539 to 0.14056, saving model to ./cell_cnn_best_weight1.hdf5
# Epoch 12/20
# 24803/24803 [==============================] - 61s 2ms/step - loss: 0.1177 - acc: 0.9607 - val_loss: 0.1493 - val_acc: 0.9419
#
# Epoch 00012: val_loss did not improve from 0.14056
# Epoch 13/20
# 24803/24803 [==============================] - 60s 2ms/step - loss: 0.1164 - acc: 0.9611 - val_loss: 0.1450 - val_acc: 0.9517
#
# Epoch 00013: val_loss did not improve from 0.14056
# Epoch 14/20
# 24803/24803 [==============================] - 60s 2ms/step - loss: 0.1145 - acc: 0.9617 - val_loss: 0.1377 - val_acc: 0.9506
#
# Epoch 00014: val_loss improved from 0.14056 to 0.13769, saving model to ./cell_cnn_best_weight1.hdf5
# Epoch 15/20
# 24803/24803 [==============================] - 60s 2ms/step - loss: 0.1102 - acc: 0.9632 - val_loss: 0.1381 - val_acc: 0.9517
#
# Epoch 00015: val_loss did not improve from 0.13769
# Epoch 16/20
# 24803/24803 [==============================] - 61s 2ms/step - loss: 0.1081 - acc: 0.9631 - val_loss: 0.1372 - val_acc: 0.9506
#
# Epoch 00016: val_loss improved from 0.13769 to 0.13717, saving model to ./cell_cnn_best_weight1.hdf5
# Epoch 17/20
# 24803/24803 [==============================] - 61s 2ms/step - loss: 0.1050 - acc: 0.9648 - val_loss: 0.1453 - val_acc: 0.9485
#
# Epoch 00017: val_loss did not improve from 0.13717
# Epoch 18/20
# 24803/24803 [==============================] - 61s 2ms/step - loss: 0.1007 - acc: 0.9658 - val_loss: 0.1450 - val_acc: 0.9466
#
# Epoch 00018: val_loss did not improve from 0.13717
# Epoch 19/20
# 24803/24803 [==============================] - 61s 2ms/step - loss: 0.1011 - acc: 0.9660 - val_loss: 0.1409 - val_acc: 0.9521
#
# Epoch 00019: val_loss did not improve from 0.13717
# Epoch 20/20
# 24803/24803 [==============================] - 60s 2ms/step - loss: 0.1006 - acc: 0.9660 - val_loss: 0.1399 - val_acc: 0.9499
#
# Epoch 00020: val_loss did not improve from 0.13717

# %% [markdown]
# ## Calling the best parameter

# %%
model.load_weights('./cell_cnn_best_weight1.hdf5')

# %% [markdown]
# ## Evaluation of learning result

# %%
#Evaluation value for test data
score = model.evaluate(x_test, y_test, verbose=0)
print('Test score:', score[0]) #The value of the loss function
print('Test accuracy:', score[1]) #Accuracy (over 98%)
# Out:
# Test score: 0.1371680052007824
# Test accuracy: 0.9506352087330688

# %%
#Learning curve
fig, ax = plt.subplots(1, 2, figsize=(12, 6))
ax[0].set_title('Training performance (Loss)')
ax[0].plot(history.epoch, history.history['loss'], label='loss')
ax[0].plot(history.epoch, history.history['val_loss'], label='val_loss')
ax[0].set(xlabel='Epoch', ylabel='Loss')
ax[0].legend()

ax[1].set_title('Training performance (Accuracy)')
ax[1].plot(history.epoch, history.history['acc'], label='acc')
ax[1].plot(history.epoch, history.history['val_acc'], label='val_acc')
ax[1].set(xlabel='Epoch', ylabel='Accuracy')
ax[1].legend(loc='best')

# %% [markdown]
# ## Predictive visualization

# %%
#Predicted value
#Store 10 images for each label
New_test = []
for for_1 in range(10):
    choice_idx = np.random.choice(np.where(y_test == (for_1%2))[0])
    New_test.append(x_test[choice_idx])
New_test = np.array(New_test)
# Estimate the label of the image
Y_test_pred = model.predict(New_test)

# %%
#Data visualization
#The upper row is the correct label, and lower row is the guess label
fig, ax = plt.subplots(1, 10, figsize=(18, 8))
for for_1 in range(10):
    ax[for_1].imshow(New_test[for_1].reshape(64,64, 3)) #Outputs the nth and subsequent test data with the value of for_2 + n
    ax[for_1].set_title(labels[(for_1%2)]+"\n"+labels[np.argmax(Y_test_pred[for_1])])
    ax[for_1].axis('off')

# %%
#Predictive visualization
#Numerals of images passed by Y axis, and X axis is estimated by neural network
plt.imshow(Y_test_pred[:10], cmap='gray', interpolation='nearest', vmin=0, vmax=1) #Y_test_predの範囲を変えることで予測の場所を変更できる
